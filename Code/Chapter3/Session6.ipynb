# %% [markdown]
# # Series-Pandas

# %%
import pandas as pd

pd.Series(["Male", "Female", "Male"])
# Out:
# 0      Male
# 1    Female
# 2      Male
# dtype: object

# %%
import numpy as np

ser = pd.Series(np.array(["Male", "Female", "Male"]))
print(ser)
# Out:
# 0      Male
# 1    Female
# 2      Male
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # DataFrame
