# %% [markdown]
# # Python: Numpy, Scikit-learn, TensorFlow

# %% [markdown]
# ## Numpy

# %%
import numpy as np

Q = np.random.randn(4, 64)
K = np.random.randn(4, 64)

scores = Q @ K.T/np.sqrt(64)
attn = np.exp(scores)/np.sum(np.exp(scores), axis = -1, keepdims = True)

# %% [markdown]
# ## Scikit-learn - Recommendation System

# %%
from sklearn.decomposition import TruncatedSVD

# Khởi tạo mô hình TruncatedSVD với 50 thành phần (n_components=50)
svd = TruncatedSVD(n_components=50)

# Trích xuất các đặc trưng ẩn của người dùng (user factors) từ ma trận đánh giá (rating_matrix)
user_factors = svd.fit_transform(rating_matrix)

# Trích xuất các đặc trưng ẩn của sản phẩm/mục (item factors)
item_factors = svd.components_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 svd = TruncatedSVD(n_components=50)
#       6 # Trích xuất các đặc trưng ẩn của người dùng (user factors) từ ma trận đánh giá (rating_matrix)
# ----> 7 user_factors = svd.fit_transform(rating_matrix)
#       9 # Trích xuất các đặc trưng ẩn của sản phẩm/mục (item factors)
#      10 item_factors = svd.components_
#
# NameError: name 'rating_matrix' is not defined

# %% [markdown]
# #  TensorFlow/Keras - Face Recognition CNN

# %%
from tensorflow.keras.layers 
import MultiHeadAttention

attn = MultiHeadAttention(num_heads=8, key_dim=64)

output = attn(query, value, key)

# %% [markdown]
# # TensorFlow - Simple Transformer Block

# %%
tf.keras.Sequential([tf.keras.layers.Embedding(vocab_size,128),
                     MultiHeadAttention(8,64),
                    tf.keras.layers.Dense(vocab_size, 
                                          activation="softmax")])
